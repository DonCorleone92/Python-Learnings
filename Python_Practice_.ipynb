# %% [markdown]
# <a href="https://colab.research.google.com/github/DonCorleone92/Python-Learnings/blob/master/Python_Practice_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Data Types:**
#
#   1. Numbers - includes integers and floats
#   2. Boolean
#   3. Strings

# %% [markdown]
# Example

# %%
x=5
print(x**2)

y= "Hello"
print(y.upper())

z = True
print(not(z))
# Out:
# 25
# HELLO
# False

# %% [markdown]
# # **Containers**
#
# ### 1. Lists
# *  Append/Pop
# *  Slicing
# *  Multiple data types in same List
# * Looping over lists / enumerate function
# * List Comprehensions

# %%
myList=[1.88,"Hello Boi",876554]
help(2)
print('Second item is '+ myList[1],'.   Second item is', myList[-1])
myList.append("Hello New Boi")
print(myList)
var=myList.pop()
print(var)
print(myList)
print('*************************')

numRange = list(range(8))
print(numRange)
print(numRange[2:5])
print(numRange[2:])
print(numRange[:7])

print('*************************')
for var in myList:
  print(var)

print('*************************')
newList=[1,2,3,4]
squareList=[]
for index,x in enumerate(newList):
  squareList.append(x**2)
  print('%d : %s' %(index+1,squareList))
# Out:
# Help on int object:
#
# class int(object)
#  |  int(x=0) -> integer
#  |  int(x, base=10) -> integer
#  |
#  |  Convert a number or string to an integer, or return 0 if no arguments
#  |  are given.  If x is a number, return x.__int__().  For floating point
#  |  numbers, this truncates towards zero.
#  |
#  |  If x is not a number or if base is given, then x must be a string,
#  |  bytes, or bytearray instance representing an integer literal in the
#  |  given base.  The literal can be preceded by '+' or '-' and be surrounded
#  |  by whitespace.  The base defaults to 10.  Valid bases are 0 and 2-36.
#  |  Base 0 means to interpret the base from the string as an integer literal.
#  |  >>> int('0b100', base=0)
#  |  4
#  |
#  |  Methods defined here:
#  |
#  |  __abs__(self, /)
#  |      abs(self)
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __and__(self, value, /)
#  |      Return self&value.
#  |
#  |  __bool__(self, /)
#  |      self != 0
#  |
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-0e0026faca9b> in <module>()
# ----> 1 id()
#
# TypeError: id() takes exactly one argument (0 given)

# %% [markdown]
# ### **Dictionaries**
#
#
# *   Getting value from key
# *   Adding item
# *   Iterations

# %%
diction={'Abhinav':'Singhal', 'Soham':'Gupta'}
print(diction)
print(diction['Abhinav'])
print('Abhinav' in diction)
diction['Shubham']='Rajput'
print(diction)
print(diction.get('Abhinavv','Not available in dictionary'))
del diction['Shubham']
print(diction)
print('*************************')
# Out:
# {'Abhinav': 'Singhal', 'Soham': 'Gupta'}
# Singhal
# True
# {'Abhinav': 'Singhal', 'Soham': 'Gupta', 'Shubham': 'Rajput'}
# Not available in dictionary
# {'Abhinav': 'Singhal', 'Soham': 'Gupta'}
# *************************

# %% [markdown]
# ### **Tuples and Sets**
#
# Sets are unordered but similar to the lists.
#
#
# Tuples are a bit complex..!!
#
#
#
# *   Set stores only the unique elements
# *   Is unordered and cannot be accessed by index.

# %% [markdown]
# ## **Session 1**

# %%
import keyword
print(keyword.kwlist)
print(len(keyword.kwlist))

# i am a comment
# i am also a comment

""" some comment
which spans over 
some line"""


s=(1,56,565,54)
s
dir(s)
help(s)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']
# 33
# Help on tuple object:
#
# class tuple(object)
#  |  tuple() -> empty tuple
#  |  tuple(iterable) -> tuple initialized from iterable's items
#  |
#  |  If the argument is a tuple, the return value is the same object.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(self, key, /)
#  |      Return self[key].
#  |
#  |  __getnewargs__(...)
#  |
# ...

# %% [markdown]
# ### **Inputs **
#
#
#
# *   Identity Operators
# *   Membership Operators

# %%
def print_name(name):
    """ 
    This function prints the name
    """
    """ Hello """
    var = input("Enter the first iput")
    print("Hello " + str(var))
    
    
print_name('Abhina')
# Out:
# Enter the first iputSinghal ..!!
# Hello Singhal ..!!

# %%
a,b,c=10,15,20
if a>b and a>c:
  print(a)
elif b>a and b>c:
  print(b)
else:
  print(c)
  
  
  
for i in range(50,101):
  if i>1:
    for j in range(2,int(i/2)+1):
      if i % j == 0:
         break 
      else:
         print(i)
# Out:
# 20
# 51
# 53
# 53
# 53
# 53
# 53
# 53
# 53
# 53
# 53
# 53
# 53
# 53
# 53
# 53
# 53
# 53
# 53
# 53
# 53
# 53
# 53
# 53
# 53
# 53
# 53
# 55
# 55
# 55
# 57
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 61
# 61
# 61
# 61
# 61
# 61
# 61
# 61
# 61
# 61
# 61
# 61
# 61
# 61
# 61
# 61
# 61
# 61
# 61
# 61
# 61
# 61
# 61
# 61
# 61
# 61
# 61
# 61
# 61
# 63
# 65
# 65
# 65
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 69
# 71
# 71
# 71
# 71
# 71
# 71
# 71
# 71
# 71
# 71
# 71
# 71
# 71
# 71
# 71
# 71
# 71
# 71
# 71
# 71
# 71
# 71
# 71
# 71
# 71
# 71
# 71
# 71
# 71
# 71
# 71
# 71
# 71
# 71
# 73
# 73
# 73
# 73
# 73
# 73
# 73
# 73
# 73
# 73
# 73
# 73
# 73
# 73
# 73
# 73
# 73
# 73
# 73
# 73
# 73
# 73
# 73
# 73
# 73
# 73
# 73
# 73
# 73
# 73
# 73
# 73
# 73
# 73
# 73
# 75
# 77
# 77
# 77
# 77
# 77
# ...

# %% [markdown]
# ## **NUMPY**

# %%
import numpy as np
from scipy import stats
import seaborn as sns


ages =[10,42,12,1,36]
#mean 
print(np.mean(ages))

#median
print(np.median(ages))

#mode
#print(stats.mode(ages)mode)

#load data
iris = sns.load_dataset("iris")

#head of datasets
iris.head(10)
#iris.tail()

plt.style.use('seaborn-white')

data=np.random.normal(size=1000)
plt.hist(data)
plt.title()
# Out:
# 20.2
# 12.0
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
import numpy as np
A = np.random.randn(4,3)
B = np.sum(A, axis = 1, keepdims = True)
B.shape
# Out:
# (4, 1)

# %%
# GRADED FUNCTION: initialize_parameters

def initialize_parameters(n_x, n_h, n_y):
    """
    Argument:
    n_x -- size of the input layer
    n_h -- size of the hidden layer
    n_y -- size of the output layer
    
    Returns:
    params -- python dictionary containing your parameters:
                    W1 -- weight matrix of shape (n_h, n_x)
                    b1 -- bias vector of shape (n_h, 1)
                    W2 -- weight matrix of shape (n_y, n_h)
                    b2 -- bias vector of shape (n_y, 1)
    """
    
    np.random.seed(2) # we set up a seed so that your output matches ours although the initialization is random.
    
    ### START CODE HERE ### (≈ 4 lines of code)
    W1 = np.random.randn(4,2)*0.01
    b1 = np.zeros((4,1))
    W2 = np.random.randn(1,4)*0.01
    b2 = np.zeros((1,1))
    ### END CODE HERE ###
    
    assert (W1.shape == (n_h, n_x))
    assert (b1.shape == (n_h, 1))
    assert (W2.shape == (n_y, n_h))
    assert (b2.shape == (n_y, 1))
    
    parameters = {"W1": W1,
                  "b1": b1,
                  "W2": W2,
                  "b2": b2}
    
    return parameters

# %%
val = initialize_parameters.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-0645a86d296b> in <module>()
# ----> 1 val = initialize_parameters.W1
#
# AttributeError: 'function' object has no attribute 'W1'
